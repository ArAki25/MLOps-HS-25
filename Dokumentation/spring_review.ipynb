# %% [markdown]
# # Sprint 1
# ## 🎯 Ziele
# - GitHub-Repository erstellen
# - Projektideen sammeln
# - Unternehmen für eine mögliche Zusammenarbeit gewinnen
#
# ## ✅ Erreicht
# - GitHub-Repository erstellt
# - Unternehmen erfolgreich angeworben
#
# ---
#
# # Sprint 2
# ## 🎯 Ziele
# - Endgültige Projektidee festlegen
#
# ## ✅ Erreicht
# - Projektidee definiert und ausgewählt
#
# ---
#
# # Sprint 3
# ## 🎯 Ziele
# - Verbindung zur SIMAP Machine-to-Machine API herstellen
# - Anbindung der SIMAP Archive API umsetzen
# - Arbeitsverteilung und Rollen im Team festlegen
#
# ## ✅ Erreicht
# - SIMAP Archive API erfolgreich verknüpft
# - Aufgaben und Rollen im Team verteilt
#
# ---

# %% [markdown]
# # Sprint 4
# ## 🎯 Ziele
# - Anfangen mit der Klassifikationsaufgabe(Daten Trainieren)
# - Fortlaufen der Dokumentation
# - Website-Erstellung
#
# ## ✅ Erreicht
